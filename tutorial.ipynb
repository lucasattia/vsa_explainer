# %%
from vsa_explainer import visualize_vsa_contributions

# %%
smiles = "C1CCCCC1O"
visualize_vsa_contributions(smiles, ["SMR_VSA7", "EState_VSA5"], normalize='flat')
# Out:
# No atoms contribute to SMR_VSA7 (range 3.0500 to 3.6300).
# ### EState_VSA5 Contributions — Total: 19.2625
# Bin range: 1.1650 to 1.5400
# Idx Sym    Value     Contrib  % of total
# --------------------------------------------
# 1   C      1.237       6.421        33.3%
# 2   C      1.330       6.421        33.3%
# 3   C      1.237       6.421        33.3%

# %%
proponaol = 'CC(C)NCC(COC1=CC=CC2=CC=CC=C21)O'
atenolol = 'CC(C)NCC(COC1=CC=C(C=C1)CC(=O)N)O'
metoprolol = 'CC(C)NCC(COC1=CC=C(C=C1)CCOC)O'
oxprenolol = 'CC(C)NCC(COC1=CC=CC=C1OCC=C)O'
smiles = [proponaol, atenolol, metoprolol, oxprenolol] 

visualize_vsa_contributions(smiles, ["VSA_EState1", "PEOE_VSA6"], grid=True, normalize="row", labels = ["Propranolol", "Atenolol", "Metoprolol", "Oxprenolol"])
# Out:
#     <div style='overflow-x:auto;'>
#     <table style='border-collapse:collapse;font-family:sans-serif;'>
#     <thead><tr><th style='padding:8px 12px;text-align:center;font-weight:500;font-size:13px;border-bottom:1px solid #ddd;min-width:80px;'>descriptor</th>
# <th style='padding:8px 12px;text-align:center;font-weight:500;font-size:13px;border-bottom:1px solid #ddd;max-width:300px;word-break:break-all;'>Propranolol</th>
# <th style='padding:8px 12px;text-align:center;font-weight:500;font-size:13px;border-bottom:1px solid #ddd;max-width:300px;word-break:break-all;'>Atenolol</th>
# <th style='padding:8px 12px;text-align:center;font-weight:500;font-size:13px;border-bottom:1px solid #ddd;max-width:300px;word-break:break-all;'>Metoprolol</th>
# <th style='padding:8px 12px;text-align:center;font-weight:500;font-size:13px;border-bottom:1px solid #ddd;max-width:300px;word-break:break-all;'>Oxprenolol</th>
# </tr></thead>
#     <tbody><tr>
# ...
